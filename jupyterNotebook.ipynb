# %% [markdown]
# Easier method: https://labs.cognitiveclass.ai/tools/jupyterlab/
# Connect to github: git pull https://github.com/zeynin/python_exercises master
# Run this notebook :)
# ![image.png](attachment:33ae1342-670d-478f-926f-0038e49f5ff2.png)

# %% [markdown]
# ### This is a test notebook for coursera
# 1. Using gp --help or gp forward-port --help a port can be opened to launch Jupyterlabs (need to figure out how to install Jupyterlabs on this gitpod instance). www.legendu.net/misc/blog/jupyter-hosts/
# 1. From gitpod Python console: pip install jupyterlab
# 1. From gitpod Python console: jupyter lab --ip 0.0.0.0 --port <container port> --allow-root
# 1. From gitpod Python console: Clicked on http://127.0.0.1:9084/?token='check_dashlane' https://9084-a92db258-3ed2-41e8-b668-96edca9c2a8d.ws-us03.gitpod.io/lab?
#     password: normal
# 1. IT WORKED! Jupyter labs launched using the token and password in another Chrome tab. Be ware of the 30 minute timeout.
#
#     ![image.png](attachment:42f8b541-fd80-431f-876f-8c22d1e56986.png)

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,4,4,3,6,7,8,9,0,3.14,7,5,5,4,3,9,2,1,1,11,1,1])
sns.distplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>
